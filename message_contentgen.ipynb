# %%
import os
import openai

openai.api_key = os.environ['OPENAI_API_KEY']

# %%
def get_response(systemcontent, usercontent):
    result = openai.ChatCompletion.create(
        messages=[
            {'role': 'system', 'content': systemcontent},
            {'role': 'user', 'content': usercontent},
        ],
        model='gpt-3.5-turbo',
        max_tokens=1024,
        temperature=0)
    response = result.choices[0].message.content
    return response

# %%
from IPython.core.magic import register_line_magic
from IPython.display import HTML, display
import json

@register_line_magic
def bg(color, cell=None):    
    script = (
        "var n = [this.closest('.cell,.jp-CodeCell')];"
        "n = n.concat([].slice.call(n[0].querySelectorAll('.input_area,.highlight,.jp-Editor')));"
        f"n.forEach(e=>e.style.background='{color}');"
        "this.parentNode.removeChild(this)"
    )
    display(HTML(f'<img src onerror="{script}" style="display:none">'))

# %%
# %bg Black
# Out:
# <img src onerror="var n = [this.closest('.cell,.jp-CodeCell')];n = n.concat([].slice.call(n[0].querySelectorAll('.input_area,.highlight,.jp-Editor')));n.forEach(e=>e.style.background='Black');this.parentNode.removeChild(this)" style="display:none">

# %%
systemcontent = '''You are a Screen Time Expert that sends short notifications to \
reduce recipients' screen time.
The notifications are concise -- no longer than two short sentences -- and are intended \
to encourage recipients to reduce their screen time.
The messages will be delivered via notifications on the recipient's device when they have \
exceeded the amount of recommended screen time.
Messages should be friendly, fun, positive, enthusiastic, and motivating.

I am a Scientist who has made a list of different types of offline activities.
I will provide this list and a brief description of each activity.
You will choose a particular interest from one category and compose a message that \
encourages the recipient to step away from their screens and engage in the chosen \
activity instead.
You will choose ONE and only one specific interest for each message.

You will design the message to be as specific and motivating as possible.
Messages should be accessible in their suggestions.
The goal is to have the recipient put down their phone and engage in the offline activity \
immediately.

Task: Generate 20 messages intended to reduce recipients' screen times by joyfully proposing \
engagement in a specific offline interest.'''

usercontent = '''reading
biking
gardening
walking in the park
painting
crocheting
drawing
knitting
writing
yoga
spin class
weightlifting
running
board games
card games
going out to eat
cooking
baking
guitar
piano
meditating
deep breathing exercises
coloring books
volunteer work
puzzles
crosswords
sudoku
chess'''

response = get_response(systemcontent, usercontent)
print(response)
# Out:
# 1. Take a break from your screen and pick up a book. Reading is a great way to relax and unwind!
# 2. Feeling cooped up? Grab your bike and hit the trails for some fresh air and exercise.
# 3. Get your hands dirty and start a garden! It's a great way to connect with nature and enjoy the outdoors.
# 4. Take a break from your screen and take a stroll through the park. You'll feel refreshed and rejuvenated!
# 5. Put down your phone and pick up a paintbrush. Painting is a great way to express yourself and relieve stress.
# 6. Crocheting is a fun and relaxing way to spend your time. Put down your phone and pick up a hook!
# 7. Drawing is a great way to unleash your creativity. Take a break from your screen and start sketching!
# 8. Knitting is a fun and rewarding hobby. Put down your phone and pick up some needles!
# 9. Feeling stressed? Take a break from your screen and start writing. It's a great way to clear your mind and express yourself.
# ...

# %%
systemcontent = '''You are a Screen Time Expert that sends short notifications to \
reduce recipients' screen time.
The notifications are concise -- no longer than two short sentences -- and are intended \
to encourage recipients to reduce their screen time.
The messages will be delivered via notifications on the recipient's device when they have \
exceeded the amount of recommended screen time.
Messages should be friendly, fun, positive, enthusiastic, and motivating.

I am a Scientist who has made a list of different types of offline activities.
I will provide this list and a brief description of each activity.
You will choose one interest from the list and compose a message that \
encourages the recipient to step away from their screens and engage in the chosen \
activity instead.

You will design the message to be as specific and motivating as possible.
Messages should be accessible in their suggestions.
Messages should NOT educate the recipient on the activity.
The goal is to have the recipient put down their phone and engage in the offline activity \
immediately.

Task: Generate one joyful message for each interest that proposes engaging in the offline activity \
to encourage the recipient to reduce their screen time.'''

usercontent = '''reading - Reading various genres of books, including fiction, non-fiction, and biographies, for entertainment, learning, and intellectual curiosity.
biking - Cycling is a versatile hobby that can be enjoyed in many different ways, whether it’s road biking, mountain biking, or just cruising around on a leisurely ride. It’s a great way to stay active and explore the outdoors.
gardening - Gardening is a popular outdoor hobby that involves growing and cultivating plants, flowers, or vegetables. It can be done in a backyard, community garden, or even indoors, and can provide numerous benefits, including stress relief and fresh produce.
roller skating - Roller skating is a fun and active hobby that can be enjoyed indoors or outdoors. It requires balance and skill, but it’s also a great way to stay active and socialize with friends.
watercolor painting - Watercolor painting involves creating illustrations using watercolor paint as a medium. It is a popular hobby for those interested in traditional art techniques.
crocheting - Crocheting involves creating fabric by looping yarn or thread with a hook. It is a popular hobby for those interested in textiles, fashion, and creating handmade gifts.
drawing - Pencil drawing involves creating illustrations using pencils as a medium. It is a popular hobby for those interested in traditional art techniques.
knitting - A hobby that has been around for centuries, knitting involves using yarn and needles to create various items such as scarves, hats, sweaters, and blankets. It’s a relaxing and meditative activity that also provides a sense of accomplishment when you finish a project.
creative writing - Creative writing is a form of self-expression where writers can experiment with different styles and genres. It includes writing fiction, non-fiction, poetry, and more.
yoga
spin class
weightlifting - weightlifters lift weights to build strength and endurance, improving their overall fitness and physique.
running
board games - Playing various board games and tabletop games that involve strategy, tactics, and chance with friends and family as a social and fun activity.
solitaire - A single-player game where the objective is to clear the board by forming runs and sets.
cooking
baking
guitar - One of the most popular hobbies – Guitar is a stringed musical instrument that produces beautiful, versatile sounds and is popular in a wide range of musical genres.
meditating - Practicing and developing mindfulness, relaxation, and self-awareness techniques for personal growth, stress reduction, or spiritual enlightenment.
coloring books
puzzles - Solving picture puzzles that involve assembling various pieces to form a complete image for mental stimulation and entertainment.
crosswords - Solving word puzzles that involve clues and a grid of intersecting letters for mental stimulation and entertainment.
sudoku - Solving various Sudoku puzzles that involve filling a grid with numbers or symbols for mental stimulation and entertainment.
chess - Playing and mastering the classic board game of strategy, tactics, and mental prowess for hobby or competition.'''

response = get_response(systemcontent, usercontent)
print(response)
# Out:
# Reading: "Put down your phone and pick up a book! Get lost in a new world, learn something new, or indulge in a juicy biography. Reading is the perfect escape from screens and a great way to unwind."
#
# Biking: "Take a break from screens and hit the road on your bike! Whether it's a leisurely ride or an intense workout, biking is a fun and active way to explore the outdoors and clear your mind."
#
# Gardening: "Step away from the screen and get your hands dirty! Gardening is a relaxing and rewarding hobby that can provide fresh produce and stress relief. Plus, there's nothing like the satisfaction of watching your plants grow."
#
# Roller Skating: "Put down your phone and lace up your skates! Roller skating is a fun and active hobby that can be enjoyed indoors or outdoors. It's a great way to stay active and socialize with friends."
#
# ...

# %%
## MESSAGES - Current best

systemcontent = '''You are a Screen Time Expert that sends short notifications to \
reduce recipients' screen time.
The notifications are extremely concise - less than two short sentences - and are intended \
to encourage recipients to reduce their screen time.
Messages should be friendly, fun, positive, enthusiastic, and motivating.

I am a Scientist who has made a list of different types of offline activities.
I will provide this list and a brief description of each activity.
You will compose a message for each interest in the list that \
encourages the recipient to step away from their screens and engage in the chosen \
activity instead.

You will design the message to be as specific and motivating as possible.
Messages should be accessible in their suggestions.
Message should assume the recipient already practices the activity.
The goal is to have the recipient put down their phone and engage in the offline activity \
immediately.

Task: Generate one fun message for each interest that proposes engaging in the offline activity \
to encourage the recipient to reduce their screen time.'''

usercontent = '''reading - Reading various genres of books, including fiction, non-fiction, and biographies, for entertainment, learning, and intellectual curiosity.
gardening - Gardening is a popular outdoor hobby that involves growing and cultivating plants, flowers, or vegetables. It can be done in a backyard, community garden, or even indoors, and can provide numerous benefits, including stress relief and fresh produce.
baking - Baking is a great hobby for honing your taste buds and getting creative in the kitchen.
guitar - One of the most popular hobbies, guitar is a stringed musical instrument that produces beautiful, versatile sounds and is popular in a wide range of musical genres.
meditating - Practicing and developing mindfulness, relaxation, and self-awareness techniques for personal growth, stress reduction, or spiritual enlightenment.
knitting - A hobby that has been around for centuries, knitting involves using yarn and needles to create various items such as scarves, hats, sweaters, and blankets. It’s a relaxing and meditative activity that also provides a sense of accomplishment when you finish a project.
coloring books - Coloring books are a fun and relaxing way to unleash your creativity.
watercolor painting - Watercolor painting involves creating illustrations using watercolor paint as a medium. It is a popular hobby for those interested in traditional art techniques.
jigsaw puzzles - Solving picture puzzles that involve assembling various pieces to form a complete image for mental stimulation and entertainment.
crosswords - Solving word puzzles that involve clues and a grid of intersecting letters for mental stimulation and entertainment.
solitaire - A single-player game where the objective is to clear the board by forming runs and sets.
walking - A quick walk outdoors is a great way to get some low-impact activity with a side of fresh air.
biking - Cycling is a versatile hobby that can be enjoyed in many different ways, whether it’s road biking, mountain biking, or just cruising around on a leisurely ride. It’s a great way to stay active and explore the outdoors.'''

response = get_response(systemcontent, usercontent)
print(response)
# Out:
# Reading: "Put down your phone and pick up a book! Get lost in a new world, learn something new, or be inspired by a biography. Reading is the perfect escape from screens."
#
# Gardening: "Step away from the screen and get your hands dirty! Gardening is a great way to relieve stress, connect with nature, and even grow your own produce. Let's get planting!"
#
# Baking: "Put down your phone and preheat the oven! Baking is a fun and creative way to satisfy your sweet tooth and impress your friends and family. Let's get baking!"
#
# Guitar: "Put down your phone and pick up your guitar! Strumming a few chords is a great way to unwind and express yourself creatively. Let's make some beautiful music!"
#
# Meditating: "Take a break from your screen and focus on your breath. Meditating is a great way to reduce stress, increase mindfulness, and improve your overall well-being. Let's find our inner peace!"
#
# ...

# %%
## PEOPLE - Current best

systemcontent = '''You are a tasked with generating a list of 10 random, made-up people.
The format for each person must follow the example I provide.
There are four age categories: young adult, adult, middle-aged, and senior.
There are three lifestyle categories: sedentary, moderate, and active.
There are fourteen activities that can be either likes or dislikes: reading, gardening, baking, \
guitar, meditating, knitting, coloring books, watercolor painting, jigsaw puzzles, crosswords,
solitaire, weightlifting, walking, and biking.
The number of likes and dislikes should vary per person.
Ensure that the likes and dislikes chosen for each person make sense as a whole.

Task: Generate 10 new people following the format I provide.'''

usercontent = '''Gender: male
Age: middle-aged
Race: white
Lifestyle: sedentary
Likes: meditating, guitar
Dislikes: biking, weightlifting, walking'''

response = get_response(systemcontent, usercontent)
print(response)
# Out:
# 1. Name: David Johnson
# Gender: Male
# Age: Young Adult
# Race: African American
# Lifestyle: Moderate
# Likes: Reading, Baking, Watercolor Painting
# Dislikes: Weightlifting, Solitaire
#
# 2. Name: Emily Davis
# Gender: Female
# Age: Senior
# Race: Asian
# Lifestyle: Sedentary
# Likes: Knitting, Jigsaw Puzzles, Crosswords
# Dislikes: Walking, Biking, Weightlifting
#
# 3. Name: Michael Thompson
# Gender: Male
# Age: Adult
# Race: Hispanic
# Lifestyle: Active
# Likes: Walking, Biking, Weightlifting
# Dislikes: Coloring Books, Solitaire
#
# 4. Name: Sarah Wilson
# Gender: Female
# Age: Middle-aged
# Race: White
# Lifestyle: Moderate
# Likes: Reading, Gardening, Baking, Watercolor Painting
# Dislikes: Weightlifting, Walking
#
# 5. Name: James Lee
# Gender: Male
# Age: Young Adult
# Race: Asian
# Lifestyle: Sedentary
# Likes: Guitar, Meditating, Solitaire
# Dislikes: Biking, Weightlifting, Walking
#
# 6. Name: Olivia Rodriguez
# Gender: Female
# Age: Adult
# Race: Hispanic
# ...

# %%
## PEOPLE - copy

systemcontent = '''You are a tasked with generating a list of 10 random, made-up people.
The format for each person must follow the example I provide.
There are four age categories: young adult, adult, middle-aged, and senior.
There are three lifestyle categories: sedentary, moderate, and active.
There are fourteen activities that can be either likes or dislikes: reading, gardening, baking, \
guitar, meditating, knitting, coloring books, watercolor painting, jigsaw puzzles, crosswords,
solitaire, weightlifting, walking, and biking.
The number of likes and dislikes should vary per person.
Ensure that the likes and dislikes chosen for each person make sense as a whole.

Task: Generate 10 new people following the format I provide.'''

usercontent = '''Gender: male
Age: middle-aged
Race: white
Lifestyle: sedentary
Likes: meditating, guitar
Dislikes: biking, weightlifting, walking'''

response = get_response(systemcontent, usercontent)
print(response)
# Out:
# 1. Name: David Johnson
# Gender: Male
# Age: Young Adult
# Race: African American
# Lifestyle: Moderate
# Likes: Reading, Baking, Watercolor Painting
# Dislikes: Weightlifting, Solitaire
#
# 2. Name: Emily Davis
# Gender: Female
# Age: Senior
# Race: Asian
# Lifestyle: Sedentary
# Likes: Knitting, Jigsaw Puzzles, Crosswords
# Dislikes: Walking, Biking, Weightlifting
#
# 3. Name: Michael Thompson
# Gender: Male
# Age: Adult
# Race: Hispanic
# Lifestyle: Active
# Likes: Walking, Biking, Weightlifting
# Dislikes: Coloring Books, Solitaire
#
# 4. Name: Sarah Wilson
# Gender: Female
# Age: Middle-aged
# Race: White
# Lifestyle: Moderate
# Likes: Reading, Gardening, Baking, Watercolor Painting
# Dislikes: Weightlifting, Walking
#
# 5. Name: James Lee
# Gender: Male
# Age: Young Adult
# Race: Asian
# Lifestyle: Sedentary
# Likes: Guitar, Meditating, Solitaire
# Dislikes: Biking, Weightlifting, Walking
#
# 6. Name: Olivia Rodriguez
# Gender: Female
# Age: Adult
# Race: Hispanic
# ...

# %%
systemcontent = '''You are a Screen Time Expert that sends short notifications to \
reduce screen time.
The notifications are concise -- no longer than two short sentences.
Your writing style is friendly, fun, positive, enthusiastic, and motivating.

I am a Scientist who has made a list of different types of offline activities.
You will choose a particular interest from my list and compose a message that \
encourages the recipient to step away from their screens and engage in the chosen \
activity instead.
For each interest, consider what might be fun about the activity and emphasize it.
You will design the message to be as specific and motivating as possible.
You must briefly mention screen time somewhere in each message.
The goal is to have the recipient step away from screens and engage in the offline activity \
immediately.

Task: Generate one message for each interest that joyfully proposes engagement \
in the offline activity in order to encourage the recipient to reduce their screen time.'''

usercontent = '''reading
biking
gardening
walking in the park
painting
crocheting
drawing
knitting
writing
yoga
weightlifting
running
board games
card games
going out to eat
cooking
baking
playing an instrument
meditating
coloring books
puzzles
crosswords
sudoku
chess'''

response = get_response(systemcontent, usercontent)
print(response)
# Out:
# Reading: "Put down your phone and pick up a book! Immerse yourself in a new world and give your eyes a break from screens."
#
# Biking: "Take a break from scrolling and hit the road! Feel the wind in your hair and the sun on your face while getting some exercise."
#
# Gardening: "Step away from the screen and get your hands dirty! Plant some flowers or veggies and enjoy the satisfaction of watching them grow."
#
# Walking in the park: "Put down your device and take a stroll in the park! Breathe in the fresh air and enjoy the beauty of nature."
#
# Painting: "Take a break from screens and let your creativity flow! Grab some paint and a canvas and express yourself through art."
#
# Crocheting: "Put down your phone and pick up some yarn! Crochet a cozy blanket or scarf and enjoy the calming rhythm of the stitches."
#
# Drawing: "Step away from the screen and let your imagination run wild! Grab a pencil and paper and create something beautiful."
#
# ...

# %%
systemcontent = '''You are a Screen Time Expert that sends short notifications to \
reduce recipients' screen time.
The messages will be delivered via notifications on the recipient's device when they have \
exceeded the amount of recommended screen time.
Messages should be friendly, fun, positive, enthusiastic, and motivating.
Your writing style is excited and enthralling.
The notifications are concise.

I am a Hobby Expert who has made a list of different types of offline activities.
You will choose one interest for each message and use this interest to compose a message that \
encourages the recipient to step away from their screens and engage in their favorite chosen \
activity instead.

You will design the message to be as specific and motivating as possible.
Messages should be accessible, specific, and enticing in their suggestions.
The goal is to have the recipient put down their phone and engage in the offline activity \
immediately.

Task: Generate 20 messages intended to reduce recipients' screen times by joyfully proposing \
engagement in a specific offline interest.'''

usercontent = '''reading
biking
gardening
walking in the park
painting
crocheting
drawing
knitting
writing
yoga
spin class
weightlifting
running
board games
card games
going out to eat
cooking
baking
guitar
piano
meditating
deep breathing exercises
coloring books
volunteer work
puzzles
crosswords
sudoku
chess'''

response = get_response(systemcontent, usercontent)
print(response)
# Out:
# 1. Hey there! Put down your phone and pick up a book. Reading is a great way to unwind and escape into a different world.
#
# 2. Feeling cooped up? Grab your bike and hit the road! The fresh air and exercise will do wonders for your mind and body.
#
# 3. Get your hands dirty and connect with nature by starting a garden. It's a great way to relax and enjoy the outdoors.
#
# 4. Take a break from screens and take a stroll in the park. The sights and sounds of nature will help you feel refreshed and rejuvenated.
#
# 5. Unleash your creativity and paint something beautiful. It's a great way to express yourself and unwind after a long day.
#
# 6. Grab your crochet hook and get to work on a new project. The repetitive motions are soothing and can help you relax.
#
# 7. Let your imagination run wild and draw something amazing. It's a great way to express yourself and let your creativity shine.
#
# ...

# %% [markdown]
# Reading: Pick up a book, whether it's fiction, non-fiction, or a genre you enjoy. Reading \
# can be a relaxing and immersive experience.
# Outdoor activities: Spend time in nature by going for walks, hikes, or bike rides. You can \
# also try activities like gardening, picnicking, or exploring local parks.
# Creative hobbies: Engage in activities that stimulate your creativity, such as painting, \
# drawing, knitting, sewing, or writing. These hobbies can be both relaxing and fulfilling.
# Exercise and fitness: Join a sports club, go for a run, practice yoga, or try out a new \
# fitness class. Physical activities are not only good for your health but also help you \
# disconnect from screens.
# Socialize offline: Plan activities with friends and family that don't involve screens, such \
# as board game nights, card games, or simply having meaningful conversations.
# Cooking and baking: Experiment with new recipes or try your hand at baking. Preparing meals \
# from scratch can be a rewarding and delicious way to spend your time.
# Learn a musical instrument: Pick up a guitar, piano, or any instrument that interests you. \
# Learning to play music can be a fulfilling and absorbing hobby.
# Mindfulness and meditation: Engage in mindfulness practices to relax and refocus your mind. \
# You can try meditation, deep breathing exercises, or even indulge in activities like \
# coloring books designed for relaxation.
# Volunteer work: Find local volunteer opportunities in your community. Whether it's helping \
# at a shelter, cleaning up the environment, or assisting with community events, volunteering \
# can be a meaningful way to spend your time.
# Indoor games and puzzles: Engage in activities like puzzles, crosswords, Sudoku, chess, or \
# other brain-teasers that challenge your mind and provide entertainment.

# %% [markdown]
# 1. Feeling cooped up? Grab your bike and explore the great outdoors!
# 2. Take a break from screens and challenge your friends to a game of billiards.
# 3. Want to try something new? Give baton twirling a spin!
# 4. Put down your phone and pick up some weights for a bodybuilding session.
# 5. Strike out your screen time and hit the bowling alley with friends.
# 6. Ready for a real-life challenge? Try boxing and see what you're made of.
# 7. Feeling adventurous? Sign up for a bull riding lesson and ride the bull!
# 8. Cheer on your friends in person by joining a cheerleading squad.
# 9. Put on a colorful show with color guard and dance your way to fun.
# 10. Get some fresh air and exercise with a leisurely bike ride.
# 11. Looking for a mental and physical challenge? Try chess boxing!
# 12. Take your game outside with a friendly game of croquet.
# 13. Put down your phone and pick up some darts for a fun game night.
# 14. Enjoy the great outdoors with a game of disc golf.
# 15. Spend some quality time with your furry friend and try dog sports.
# 16. Ready for a challenge? Try a duathlon and push your limits.
# 17. Take to the skies with falconry and experience the thrill of the hunt.
# 18. Fencing is a fun and competitive hobby that will keep you on your toes.
# 19. Reel in some fun and try your hand at a fish tournament.
# 20. Get some fresh air and exercise with a round of golf.
